# %%
import pandas as pd
import chess
import torch
from torch.utils.data import Dataset

df = pd.read_csv("./dataset/Lichess_clean_2016_80k_games.csv")
print("Rows:", len(df))
df.head()
# Out:
# Rows: 79788
#          White           Black Result  ECO  \
# 0  Mescalero25          fialho    1-0  C00
# 1   theosis101      sebafreire    1-0  A43
# 2    BrettDale  Viriskensoshir    0-1  B72
# 3        borgs       IntiTupac    0-1  A13
# 4    Aquariano      Moszkowski    1-0  A40
#
#                                       Opening  \
# 0        French Defense: King's Indian Attack
# 1                          Old Benoni Defense
# 2  Sicilian Defense: Dragon, Classical Attack
# 3       English Opening: Agincourt Defense #3
# 4       Englund Gambit Complex: Soller Gambit
#
#                                                Moves  MoveCount  WhiteWin  \
# 0  e4 e6 d3 d5 Nd2 dxe4 Nxe4 b6 g3 Bb7 Bg2 Be7 Nf...         77         1
# 1  d4 c5 c4 cxd4 Nf3 Nc6 e3 e6 exd4 Nf6 Nc3 d5 cx...         55         1
# 2  e4 c5 Nf3 d6 d4 cxd4 Nxd4 Nf6 Nc3 g6 Be2 Bg7 B...         54         0
# 3  c4 e6 Nf3 a6 g3 g6 Bg2 Bg7 O-O Ne7 d4 d5 cxd5 ...         92         0
# ...
